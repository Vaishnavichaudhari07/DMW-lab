# %%
#import numpy,pandas and matplotlib libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#read csv file into dataframe object data
data=pd.read_csv("ds_salaries.csv")

# %%
#print data file
data
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
#display first 10 rows of dataset
data.head(10)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
# 5           5       2020               EN              FT
# 6           6       2020               SE              FT
# 7           7       2020               MI              FT
# 8           8       2020               MI              FT
# 9           9       2020               SE              FT
#
#                     job_title    salary salary_currency  salary_in_usd  \
# 0              Data Scientist     70000             EUR          79833
# 1  Machine Learning Scientist    260000             USD         260000
# 2           Big Data Engineer     85000             GBP         109024
# ...

# %%
# Print all the columns name
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
# Print the Data Types of Each column
data.dtypes
# Out:
# Unnamed: 0             int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
#print the max column and rows
data.shape
# Out:
# (607, 12)

# %%
 #To view some basic statistical details like percentile, mean,std,etc.of a data frame
data.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %%
#To display information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
 #To give sum of null values or to check how many null valued are there
data.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
data[data.work_year> 5] #to get data whoes work year is greater then 5
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
data[100:610] #To print columns from 100 to 610
# Out:
#      Unnamed: 0  work_year experience_level employment_type        job_title  \
# 100         100       2021               MI              FT     Data Analyst
# 101         101       2021               SE              FT    Data Engineer
# 102         102       2021               MI              FT  BI Data Analyst
# 103         103       2021               MI              FT     Data Analyst
# 104         104       2021               MI              FT   Data Scientist
# ..          ...        ...              ...             ...              ...
# 602         602       2022               SE              FT    Data Engineer
# 603         603       2022               SE              FT    Data Engineer
# 604         604       2022               SE              FT     Data Analyst
# 605         605       2022               SE              FT     Data Analyst
# 606         606       2022               MI              FT     AI Scientist
#
# ...

# %%
# Data Integration

# %%
#To read 2 datasets
d1=pd.read_csv('student1.csv')
d2=pd.read_csv('student2.csv')

# %%
#display content of dataset 1
d1
# Out:
#    Sr. No.  Roll Number Name  STD DIV
# 0        1           58    A    1   A
# 1        2           84    b    2   A
# 2        3           74    c    3   A
# 3        4            4    d    4   A
# 4        5            5    e    5   A
# 5        6            6    f    1   A
# 6        7            7    g    3   A
# 7        8            8    h    5   A
# 8        9            9    i    2   A
# 9       10           10    j    1   A

# %%
#display content of dataset 1
d2
# Out:
#    Sr. No.  Roll Number Name  Phone no Address
# 0        1           58    A         1       A
# 1        2           84    b         2       A
# 2        3           74    c         3       A
# 3        4            4    d         4       A
# 4        5            5    e         5       A
# 5        6            6    f         1       A
# 6        7            7    g         3       A
# 7        8            8    h         5       A
# 8        9            9    i         2       A
# 9       10           10    j         1       A

# %%
d1.isna() #To check null Values in data 1
# Out:
#    Sr. No.  Roll Number   Name    STD    DIV
# 0    False        False  False  False  False
# 1    False        False  False  False  False
# 2    False        False  False  False  False
# 3    False        False  False  False  False
# 4    False        False  False  False  False
# 5    False        False  False  False  False
# 6    False        False  False  False  False
# 7    False        False  False  False  False
# 8    False        False  False  False  False
# 9    False        False  False  False  False

# %%
d2.isna() #To check Null values of data2
# Out:
#    Sr. No.  Roll Number   Name  Phone no  Address
# 0    False        False  False     False    False
# 1    False        False  False     False    False
# 2    False        False  False     False    False
# 3    False        False  False     False    False
# 4    False        False  False     False    False
# 5    False        False  False     False    False
# 6    False        False  False     False    False
# 7    False        False  False     False    False
# 8    False        False  False     False    False
# 9    False        False  False     False    False

# %%
d3=pd.concat([d1,d2])
d3
#to integrate two dataset
# Out:
#    Sr. No.  Roll Number Name  STD  DIV  Phone no Address
# 0        1           58    A  1.0    A       NaN     NaN
# 1        2           84    b  2.0    A       NaN     NaN
# 2        3           74    c  3.0    A       NaN     NaN
# 3        4            4    d  4.0    A       NaN     NaN
# 4        5            5    e  5.0    A       NaN     NaN
# 5        6            6    f  1.0    A       NaN     NaN
# 6        7            7    g  3.0    A       NaN     NaN
# 7        8            8    h  5.0    A       NaN     NaN
# 8        9            9    i  2.0    A       NaN     NaN
# 9       10           10    j  1.0    A       NaN     NaN
# 0        1           58    A  NaN  NaN       1.0       A
# 1        2           84    b  NaN  NaN       2.0       A
# 2        3           74    c  NaN  NaN       3.0       A
# 3        4            4    d  NaN  NaN       4.0       A
# 4        5            5    e  NaN  NaN       5.0       A
# ...

# %%
#Data Transformation

# %%
d1.hist() #in histogram representation of data 1
# Out:
# array([[<AxesSubplot:title={'center':'Sr. No.'}>,
#         <AxesSubplot:title={'center':'Roll Number'}>],
#        [<AxesSubplot:title={'center':'STD'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
d2.hist() #in histogram representation of data 2
# Out:
# array([[<AxesSubplot:title={'center':'Sr. No.'}>,
#         <AxesSubplot:title={'center':'Roll Number'}>],
#        [<AxesSubplot:title={'center':'Phone no'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data.hist() #in histogram representation of data
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'work_year'}>],
#        [<AxesSubplot:title={'center':'salary'}>,
#         <AxesSubplot:title={'center':'salary_in_usd'}>],
#        [<AxesSubplot:title={'center':'remote_ratio'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
a=np.array(d1['STD'])

# %%
plt.pie(a)
# Out:
# ([<matplotlib.patches.Wedge at 0x2b39b8d6250>,
# ...
#  [Text(1.0925621934054306, 0.12770220648491118, ''),
#   Text(0.9829959026438434, 0.49367910162920164, ''),
#   Text(0.5499999925673781, 0.9526279484541089, ''),
#   Text(-0.31548357059890975, 1.0537884591710818, ''),
#   Text(-1.070349357197973, 0.2536774596724867, ''),
#   Text(-0.9829959141992366, -0.49367907862052174, ''),
#   Text(-0.6568744654063434, -0.882335501210923, ''),
#   Text(0.3154835212675113, -1.0537884739399326, ''),
#   Text(0.9829958795330556, -0.49367914764656073, ''),
#   Text(1.0925621874272575, -0.12770225763143894, '')])

# %%
#Data Reduction

# %%
#to display dataset
d3
# Out:
#    Sr. No.  Roll Number Name  STD  DIV  Phone no Address
# 0        1           58    A  1.0    A       NaN     NaN
# 1        2           84    b  2.0    A       NaN     NaN
# 2        3           74    c  3.0    A       NaN     NaN
# 3        4            4    d  4.0    A       NaN     NaN
# 4        5            5    e  5.0    A       NaN     NaN
# 5        6            6    f  1.0    A       NaN     NaN
# 6        7            7    g  3.0    A       NaN     NaN
# 7        8            8    h  5.0    A       NaN     NaN
# 8        9            9    i  2.0    A       NaN     NaN
# 9       10           10    j  1.0    A       NaN     NaN
# 0        1           58    A  NaN  NaN       1.0       A
# 1        2           84    b  NaN  NaN       2.0       A
# 2        3           74    c  NaN  NaN       3.0       A
# 3        4            4    d  NaN  NaN       4.0       A
# 4        5            5    e  NaN  NaN       5.0       A
# ...

# %%
#To reduce unnecessary coulmn and store it in d4
d4=d3.drop(['Address'],axis=1)

# %%
d4
# Out:
#    Sr. No.  Roll Number Name  STD  DIV  Phone no
# 0        1           58    A  1.0    A       NaN
# 1        2           84    b  2.0    A       NaN
# 2        3           74    c  3.0    A       NaN
# 3        4            4    d  4.0    A       NaN
# 4        5            5    e  5.0    A       NaN
# 5        6            6    f  1.0    A       NaN
# 6        7            7    g  3.0    A       NaN
# 7        8            8    h  5.0    A       NaN
# 8        9            9    i  2.0    A       NaN
# 9       10           10    j  1.0    A       NaN
# 0        1           58    A  NaN  NaN       1.0
# 1        2           84    b  NaN  NaN       2.0
# 2        3           74    c  NaN  NaN       3.0
# 3        4            4    d  NaN  NaN       4.0
# 4        5            5    e  NaN  NaN       5.0
# 5        6            6    f  NaN  NaN       1.0
# 6        7            7    g  NaN  NaN       3.0
# 7        8            8    h  NaN  NaN       5.0
# ...
